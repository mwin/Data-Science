# %% [markdown]
# <a href="https://colab.research.google.com/github/mwin/Data-Science/blob/main/Unit_4_Challenge_Tier_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively.
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file.
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# 0    E12000002          E12000003     E12000004     E12000005       E12000006
# 1  43958.48001        44803.42878   45544.52227   48527.52339      56701.5961
# 2  43925.42289        44528.80721   46051.57066   49341.29029     56593.59475
# 3   44434.8681        45200.46775   45383.82395   49442.17973     56171.18278
# 4   44267.7796        45614.34341   46124.23045   49455.93299     56567.89582
#
#         LONDON   SOUTH EAST   SOUTH WEST Unnamed: 47      England
# 0    E12000007    E12000008    E12000009         NaN    E92000001
# 1  74435.76052  64018.87894   54705.1579         NaN  53202.77128
# 2  72777.93709  63715.02399  54356.14843         NaN   53096.1549
# 3  73896.84204  64113.60858  53583.07667         NaN   53201.2843
# 4  74455.28754  64623.22395  54786.01938         NaN   53590.8548
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# 0    E12000002          E12000003     E12000004     E12000005       E12000006
# 1  43958.48001        44803.42878   45544.52227   48527.52339      56701.5961
# 2  43925.42289        44528.80721   46051.57066   49341.29029     56593.59475
# 3   44434.8681        45200.46775   45383.82395   49442.17973     56171.18278
# 4   44267.7796        45614.34341   46124.23045   49455.93299     56567.89582
#
#         LONDON   SOUTH EAST   SOUTH WEST Unnamed: 47      England
# 0    E12000007    E12000008    E12000009         NaN    E92000001
# 1  74435.76052  64018.87894   54705.1579         NaN  53202.77128
# 2  72777.93709  63715.02399  54356.14843         NaN   53096.1549
# 3  73896.84204  64113.60858  53583.07667         NaN   53201.2843
# 4  74455.28754  64623.22395  54786.01938         NaN   53590.8548
#
# [5 rows x 49 columns]

# %%
properties_renamed = properties.T.reset_index()
properties_renamed.columns = properties_renamed.iloc[0,:]
properties_renamed.head()
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1          94900.51244          110128.0423          112329.4376  ...
# 2          53700.34831          52113.12157          52232.19868  ...
# 3          90107.23471          91441.24768          92361.31512  ...
# 4          64252.32335          63722.70055          64432.60005  ...
#
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00  \
# 0  2023-07-01 00:00:00  2023-08-01 00:00:00  2023-09-01 00:00:00
# 1              1008012               936702               896682
# 2               338138               339563               337649
# 3               589701               591563               588233
# 4               397933               396647               397348
#
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00  \
# 0  2023-10-01 00:00:00  2023-11-01 00:00:00  2023-12-01 00:00:00
# 1               854727               837486               804808
# 2               337933               341026               337725
# 3               579669               581615               581371
# 4               393723               398080               394474
#
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00  \
# 0  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00
# 1               798179               785962               755712
# 2               328359               319809               326650
# 3               581246               573653               582371
# 4               395468               395439               400146
#
# 0  2024-04-01 00:00:00
# 0  2024-04-01 00:00:00
# 1               778946
# 2               333425
# 3               573010
# 4               404557
#
# [5 rows x 354 columns]

# %%
properties_renamed = properties_renamed.drop([0])
properties_renamed.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 2              Barnet  E09000003         93284.51832         93190.16963
# 3              Bexley  E09000004         64958.09036         64787.92069
# 4               Brent  E09000005         71306.56698         72022.26197
# 5             Bromley  E09000006         81671.47692         81657.55944
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         51268.96956         53133.50526         53042.24852
# 2         92247.52435         90762.87492         90258.00033
# 3         64367.49344         64277.66881         63997.13588
# 4         72015.76274         72965.63094         73704.04743
# 5         81449.31143         81124.41227         81542.61561
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         53700.34831         52113.12157         52232.19868  ...
# 2         90107.23471         91441.24768         92361.31512  ...
# 3         64252.32335         63722.70055         64432.60005  ...
# 4         74310.48167         74127.03788          73547.0411  ...
# 5         82382.83435         82898.52264         82054.37156  ...
#
# 0 2023-07-01 00:00:00 2023-08-01 00:00:00 2023-09-01 00:00:00  \
# 1              338138              339563              337649
# 2              589701              591563              588233
# 3              397933              396647              397348
# 4              512835              530319              529274
# 5              500124              499729              499642
#
# 0 2023-10-01 00:00:00 2023-11-01 00:00:00 2023-12-01 00:00:00  \
# 1              337933              341026              337725
# 2              579669              581615              581371
# 3              393723              398080              394474
# 4              528081              515182              507592
# 5              497486              493017              493507
#
# 0 2024-01-01 00:00:00 2024-02-01 00:00:00 2024-03-01 00:00:00  \
# 1              328359              319809              326650
# 2              581246              573653              582371
# 3              395468              395439              400146
# 4              520722              527606              510427
# 5              494361              493823              491226
#
# 0 2024-04-01 00:00:00
# 1              333425
# 2              573010
# 3              404557
# 4              488462
# 5              485561
#
# [5 rows x 354 columns]

# %%
properties_renamed = properties_renamed.reset_index(drop=True)
properties_renamed.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 1              Barnet  E09000003         93284.51832         93190.16963
# 2              Bexley  E09000004         64958.09036         64787.92069
# 3               Brent  E09000005         71306.56698         72022.26197
# 4             Bromley  E09000006         81671.47692         81657.55944
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0         51268.96956         53133.50526         53042.24852
# 1         92247.52435         90762.87492         90258.00033
# 2         64367.49344         64277.66881         63997.13588
# 3         72015.76274         72965.63094         73704.04743
# 4         81449.31143         81124.41227         81542.61561
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 0         53700.34831         52113.12157         52232.19868  ...
# 1         90107.23471         91441.24768         92361.31512  ...
# 2         64252.32335         63722.70055         64432.60005  ...
# 3         74310.48167         74127.03788          73547.0411  ...
# 4         82382.83435         82898.52264         82054.37156  ...
#
# 0 2023-07-01 00:00:00 2023-08-01 00:00:00 2023-09-01 00:00:00  \
# 0              338138              339563              337649
# 1              589701              591563              588233
# 2              397933              396647              397348
# 3              512835              530319              529274
# 4              500124              499729              499642
#
# 0 2023-10-01 00:00:00 2023-11-01 00:00:00 2023-12-01 00:00:00  \
# 0              337933              341026              337725
# 1              579669              581615              581371
# 2              393723              398080              394474
# 3              528081              515182              507592
# 4              497486              493017              493507
#
# 0 2024-01-01 00:00:00 2024-02-01 00:00:00 2024-03-01 00:00:00  \
# 0              328359              319809              326650
# 1              581246              573653              582371
# 2              395468              395439              400146
# 3              520722              527606              510427
# 4              494361              493823              491226
#
# 0 2024-04-01 00:00:00
# 0              333425
# 1              573010
# 2              404557
# 3              488462
# 4              485561
#
# [5 rows x 354 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_renamed_columns = properties_renamed.rename(columns={"Unnamed: 0": "Borough", pd.NaT : "ID"})

# %%
properties_renamed_columns.head()
# Out:
# 0             Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 1              Barnet  E09000003         93284.51832         93190.16963
# 2              Bexley  E09000004         64958.09036         64787.92069
# 3               Brent  E09000005         71306.56698         72022.26197
# 4             Bromley  E09000006         81671.47692         81657.55944
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0         51268.96956         53133.50526         53042.24852
# 1         92247.52435         90762.87492         90258.00033
# 2         64367.49344         64277.66881         63997.13588
# 3         72015.76274         72965.63094         73704.04743
# 4         81449.31143         81124.41227         81542.61561
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 0         53700.34831         52113.12157         52232.19868  ...
# 1         90107.23471         91441.24768         92361.31512  ...
# 2         64252.32335         63722.70055         64432.60005  ...
# 3         74310.48167         74127.03788          73547.0411  ...
# 4         82382.83435         82898.52264         82054.37156  ...
#
# 0 2023-07-01 00:00:00 2023-08-01 00:00:00 2023-09-01 00:00:00  \
# 0              338138              339563              337649
# 1              589701              591563              588233
# 2              397933              396647              397348
# 3              512835              530319              529274
# 4              500124              499729              499642
#
# 0 2023-10-01 00:00:00 2023-11-01 00:00:00 2023-12-01 00:00:00  \
# 0              337933              341026              337725
# 1              579669              581615              581371
# 2              393723              398080              394474
# 3              528081              515182              507592
# 4              497486              493017              493507
#
# 0 2024-01-01 00:00:00 2024-02-01 00:00:00 2024-03-01 00:00:00  \
# 0              328359              319809              326650
# 1              581246              573653              582371
# 2              395468              395439              400146
# 3              520722              527606              510427
# 4              494361              493823              491226
#
# 0 2024-04-01 00:00:00
# 0              333425
# 1              573010
# 2              404557
# 3              488462
# 4              485561
#
# [5 rows x 354 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_renamed_columns = pd.melt(properties_renamed_columns,id_vars=["Borough","ID"])

# %%
properties_renamed_columns.head()
# Out:
#               Borough         ID          0        value
# 0  Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 1              Barnet  E09000003 1995-01-01  93284.51832
# 2              Bexley  E09000004 1995-01-01  64958.09036
# 3               Brent  E09000005 1995-01-01  71306.56698
# 4             Bromley  E09000006 1995-01-01  81671.47692

# %%
properties_named = properties_renamed_columns.rename(columns={0:"Date", "value":"Average_Price"})
properties_named.head()
# Out:
#               Borough         ID       Date Average_Price
# 0  Barking & Dagenham  E09000002 1995-01-01    50460.2266
# 1              Barnet  E09000003 1995-01-01   93284.51832
# 2              Bexley  E09000004 1995-01-01   64958.09036
# 3               Brent  E09000005 1995-01-01   71306.56698
# 4             Bromley  E09000006 1995-01-01   81671.47692

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_named.dtypes
# Out:
# Borough                  object
# ID                       object
# Date             datetime64[ns]
# Average_Price            object
# dtype: object

# %%
properties_named["Average_Price"] = pd.to_numeric(properties_named["Average_Price"])

# %%
properties_named.dtypes
# Out:
# Borough                  object
# ID                       object
# Date             datetime64[ns]
# Average_Price           float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
properties_named.dtypes
properties_named.count()
# Out:
# Borough          16544
# ID               15488
# Date             16544
# Average_Price    15488
# dtype: int64

# %%
properties_named.isna().any()
# Out:
# Borough          False
# ID                True
# Date             False
# Average_Price     True
# dtype: bool

# %%
properties_named['Borough'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Unnamed: 34', 'Inner London', 'Outer London', 'Unnamed: 37',
#        'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
properties_named[properties_named["Borough"] == 'Unnamed: 37']
# Out:
#            Borough   ID       Date  Average_Price
# 35     Unnamed: 37  NaN 1995-01-01            NaN
# 82     Unnamed: 37  NaN 1995-02-01            NaN
# 129    Unnamed: 37  NaN 1995-03-01            NaN
# 176    Unnamed: 37  NaN 1995-04-01            NaN
# 223    Unnamed: 37  NaN 1995-05-01            NaN
# ...            ...  ...        ...            ...
# 16344  Unnamed: 37  NaN 2023-12-01            NaN
# 16391  Unnamed: 37  NaN 2024-01-01            NaN
# 16438  Unnamed: 37  NaN 2024-02-01            NaN
# 16485  Unnamed: 37  NaN 2024-03-01            NaN
# 16532  Unnamed: 37  NaN 2024-04-01            NaN
#
# [352 rows x 4 columns]

# %%
properties_named[properties_named["Borough"] == 'Unnamed: 47']
# Out:
#            Borough   ID       Date  Average_Price
# 45     Unnamed: 47  NaN 1995-01-01            NaN
# 92     Unnamed: 47  NaN 1995-02-01            NaN
# 139    Unnamed: 47  NaN 1995-03-01            NaN
# 186    Unnamed: 47  NaN 1995-04-01            NaN
# 233    Unnamed: 47  NaN 1995-05-01            NaN
# ...            ...  ...        ...            ...
# 16354  Unnamed: 47  NaN 2023-12-01            NaN
# 16401  Unnamed: 47  NaN 2024-01-01            NaN
# 16448  Unnamed: 47  NaN 2024-02-01            NaN
# 16495  Unnamed: 47  NaN 2024-03-01            NaN
# 16542  Unnamed: 47  NaN 2024-04-01            NaN
#
# [352 rows x 4 columns]

# %%
properties_named[properties_named["Borough"] == 'Unnamed: 34']
# Out:
#            Borough   ID       Date  Average_Price
# 32     Unnamed: 34  NaN 1995-01-01            NaN
# 79     Unnamed: 34  NaN 1995-02-01            NaN
# 126    Unnamed: 34  NaN 1995-03-01            NaN
# 173    Unnamed: 34  NaN 1995-04-01            NaN
# 220    Unnamed: 34  NaN 1995-05-01            NaN
# ...            ...  ...        ...            ...
# 16341  Unnamed: 34  NaN 2023-12-01            NaN
# 16388  Unnamed: 34  NaN 2024-01-01            NaN
# 16435  Unnamed: 34  NaN 2024-02-01            NaN
# 16482  Unnamed: 34  NaN 2024-03-01            NaN
# 16529  Unnamed: 34  NaN 2024-04-01            NaN
#
# [352 rows x 4 columns]

# %%
properties_Na = properties_named.dropna()
print(properties_Na)
# Out:
#                   Borough         ID       Date  Average_Price
# 0      Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 1                  Barnet  E09000003 1995-01-01    93284.51832
# 2                  Bexley  E09000004 1995-01-01    64958.09036
# 3                   Brent  E09000005 1995-01-01    71306.56698
# 4                 Bromley  E09000006 1995-01-01    81671.47692
# ...                   ...        ...        ...            ...
# 16538     EAST OF ENGLAND  E12000006 2024-04-01   335448.00000
# 16539              LONDON  E12000007 2024-04-01   501880.00000
# 16540          SOUTH EAST  E12000008 2024-04-01   375067.00000
# 16541          SOUTH WEST  E12000009 2024-04-01   317911.00000
# 16543             England  E92000001 2024-04-01   298229.00000
#
# [15488 rows x 4 columns]

# %%
properties_Na['Borough'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype=object)

# %%
properties_Na.isna().any()
# Out:
# Borough          False
# ID               False
# Date             False
# Average_Price    False
# dtype: bool

# %%
properties_Na.head()
# Out:
#               Borough         ID       Date  Average_Price
# 0  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 1              Barnet  E09000003 1995-01-01    93284.51832
# 2              Bexley  E09000004 1995-01-01    64958.09036
# 3               Brent  E09000005 1995-01-01    71306.56698
# 4             Bromley  E09000006 1995-01-01    81671.47692

# %%
properties_Na.dtypes
# Out:
# Borough                  object
# ID                       object
# Date             datetime64[ns]
# Average_Price           float64
# dtype: object

# %%
properties_Na["Borough"].nunique()
# Out:
# 44

# %%
list_of_non_boroughs = [
       'Inner London', 'Outer London',  'NORTH EAST',
       'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
       'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
       'SOUTH WEST',  'England' , 'City of London'
]

# %%
properties_Na = properties_Na[properties_Na["Borough"].isin(list_of_non_boroughs) == False]

# %%
properties_Na["Borough"].nunique()
# Out:
# 32

# %%
properties_Na.head(100)
# Out:
#                 Borough         ID       Date  Average_Price
# 0    Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 1                Barnet  E09000003 1995-01-01    93284.51832
# 2                Bexley  E09000004 1995-01-01    64958.09036
# 3                 Brent  E09000005 1995-01-01    71306.56698
# 4               Bromley  E09000006 1995-01-01    81671.47692
# ..                  ...        ...        ...            ...
# 125         Westminster  E09000033 1995-03-01   132260.34170
# 141  Barking & Dagenham  E09000002 1995-04-01    53133.50526
# 142              Barnet  E09000003 1995-04-01    90762.87492
# 143              Bexley  E09000004 1995-04-01    64277.66881
# 144               Brent  E09000005 1995-04-01    72965.63094
#
# [100 rows x 4 columns]

# %%
properties_Na.dtypes
# Out:
# Borough                  object
# ID                       object
# Date             datetime64[ns]
# Average_Price           float64
# dtype: object

# %%
properties_Na['Borough'].unique()
# Out:
# array(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley',
#        'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype=object)

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
Harrow_Avg_price = properties_Na[properties_Na['Borough'] == 'Harrow']

Harrow_plot = Harrow_Avg_price.plot(kind = 'line', x = 'Date', y = 'Average_Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
properties_Na['Year'] = properties_Na['Date'].apply(lambda t: t.year)

properties_Na.tail()
# Out:
#               Borough         ID       Date  Average_Price  Year
# 16524          Sutton  E09000029 2024-04-01       420492.0  2024
# 16525   Tower Hamlets  E09000030 2024-04-01       440574.0  2024
# 16526  Waltham Forest  E09000031 2024-04-01       477622.0  2024
# 16527      Wandsworth  E09000032 2024-04-01       620731.0  2024
# 16528     Westminster  E09000033 2024-04-01       969527.0  2024

# %%
dfg = properties_Na.groupby(["Borough",'Year'])['Average_Price'].mean().sort_values(ascending=False)

# %%
dfg.sample(50)
# Out:
# Borough               Year
# Bromley               2013    2.966692e+05
# Hackney               2012    3.254925e+05
# Greenwich             2013    2.533993e+05
# Merton                2000    1.516054e+05
# Camden                2020    8.335700e+05
# Harrow                2009    2.630361e+05
# Richmond upon Thames  2020    6.811753e+05
# Greenwich             2017    3.917499e+05
# Havering              2019    3.646356e+05
# Newham                2003    1.684375e+05
# Lambeth               2018    5.115364e+05
# Camden                2019    8.481576e+05
# Hackney               2008    3.117705e+05
# Merton                2001    1.670462e+05
# Croydon               2012    2.218172e+05
# Kensington & Chelsea  1997    2.466556e+05
# Croydon               1997    7.767427e+04
# Sutton                2015    3.229321e+05
# Tower Hamlets         2013    3.090510e+05
# Waltham Forest        2018    4.408594e+05
# Ealing                2024    5.195678e+05
# Bexley                2020    3.433264e+05
# Harrow                2010    2.921660e+05
# Lambeth               2003    2.033772e+05
# Waltham Forest        2020    4.512326e+05
# Barnet                2004    2.718541e+05
# Kensington & Chelsea  2002    4.603825e+05
# Waltham Forest        2002    1.481375e+05
# Tower Hamlets         1999    1.130353e+05
# Richmond upon Thames  2018    6.526654e+05
# Merton                2014    4.199768e+05
# Hillingdon            2001    1.452937e+05
# Ealing                2022    5.331701e+05
# Havering              2013    2.264288e+05
# Islington             2001    2.198184e+05
# Havering              2007    2.335349e+05
# Newham                2019    3.639561e+05
# Camden                1999    1.910907e+05
# Bexley                2006    1.918311e+05
# Bromley               2009    2.499093e+05
# Islington             2013    4.957662e+05
# Lewisham              1997    6.615070e+04
# Kensington & Chelsea  2023    1.359142e+06
# Greenwich             2000    1.101630e+05
# Camden                1996    1.338105e+05
# Enfield               2009    2.219931e+05
# Brent                 1995    7.302984e+04
# Lewisham              1996    5.988661e+04
# Bexley                2010    2.008742e+05
# Camden                2016    8.071190e+05
# Name: Average_Price, dtype: float64

# %%
dfg = dfg.reset_index()
dfg.head()
# Out:
#                 Borough  Year  Average_Price
# 0  Kensington & Chelsea  2022   1.447670e+06
# 1  Kensington & Chelsea  2018   1.363880e+06
# 2  Kensington & Chelsea  2023   1.359142e+06
# 3  Kensington & Chelsea  2017   1.344540e+06
# 4  Kensington & Chelsea  2021   1.343815e+06

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
dfg[dfg["Borough"]=='Kensington & Chelsea']
# Out:
#                   Borough  Year  Average_Price
# 0    Kensington & Chelsea  2022   1.447670e+06
# 1    Kensington & Chelsea  2018   1.363880e+06
# 2    Kensington & Chelsea  2023   1.359142e+06
# 3    Kensington & Chelsea  2017   1.344540e+06
# 4    Kensington & Chelsea  2021   1.343815e+06
# 5    Kensington & Chelsea  2020   1.320568e+06
# 6    Kensington & Chelsea  2015   1.302103e+06
# 7    Kensington & Chelsea  2014   1.288406e+06
# 8    Kensington & Chelsea  2016   1.276235e+06
# 9    Kensington & Chelsea  2019   1.235957e+06
# 10   Kensington & Chelsea  2024   1.197175e+06
# 11   Kensington & Chelsea  2013   1.126573e+06
# 17   Kensington & Chelsea  2012   1.009045e+06
# 24   Kensington & Chelsea  2011   9.085651e+05
# 32   Kensington & Chelsea  2010   8.373150e+05
# 37   Kensington & Chelsea  2008   7.848347e+05
# 47   Kensington & Chelsea  2007   7.466792e+05
# 54   Kensington & Chelsea  2009   7.051875e+05
# 83   Kensington & Chelsea  2006   5.980075e+05
# 139  Kensington & Chelsea  2005   5.202062e+05
# 149  Kensington & Chelsea  2004   5.121867e+05
# 214  Kensington & Chelsea  2003   4.604906e+05
# 215  Kensington & Chelsea  2002   4.603825e+05
# 279  Kensington & Chelsea  2001   4.201295e+05
# 345  Kensington & Chelsea  2000   3.768022e+05
# 433  Kensington & Chelsea  1999   3.114554e+05
# 515  Kensington & Chelsea  1998   2.683501e+05
# 566  Kensington & Chelsea  1997   2.466556e+05
# 672  Kensington & Chelsea  1996   2.071567e+05
# 705  Kensington & Chelsea  1995   1.928573e+05

# %%
def price_ratio(dfg_filter_borough):

    # definition of price_1998 and price_2018
    price_1998 = float(dfg_filter_borough[dfg_filter_borough['Year'] == 1998]['Average_Price'])
    price_2018 = float(dfg_filter_borough[dfg_filter_borough['Year'] == 2018]['Average_Price'])

    ratio_prices = price_2018 / price_1998

    return (ratio_prices)

# An example fxn call

#printing with .format()
"The ratio of avg_home_price (2018/1998) for the Kensington & Chelsea borrough is: {}".format(price_ratio(dfg[dfg["Borough"] == 'Kensington & Chelsea']))

#printing with f"str{}
f"The ratio of avg_home_price (2018/1998) for the Kensington & Chelsea borrough is: {price_ratio(dfg[dfg['Borough'] == 'Kensington & Chelsea'])}"
# Out:
# <ipython-input-60-251532dfb792>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price_1998 = float(dfg_filter_borough[dfg_filter_borough['Year'] == 1998]['Average_Price'])
# <ipython-input-60-251532dfb792>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price_2018 = float(dfg_filter_borough[dfg_filter_borough['Year'] == 2018]['Average_Price'])
# 'The ratio of avg_home_price (2018/1998) for the Kensington & Chelsea borrough is: 5.082465066092464'

# %%
ratios = {}

# %%
for item in dfg['Borough'].unique():

    df_new = dfg[dfg['Borough'] == item]
    ratios[item] = price_ratio(df_new)

print(ratios)
# Out:
# <ipython-input-60-251532dfb792>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price_1998 = float(dfg_filter_borough[dfg_filter_borough['Year'] == 1998]['Average_Price'])
# <ipython-input-60-251532dfb792>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price_2018 = float(dfg_filter_borough[dfg_filter_borough['Year'] == 2018]['Average_Price'])
# {'Kensington & Chelsea': 5.082465066092464, 'Westminster': 5.353565392605412, 'Camden': 4.935353408884261, 'Hammersmith & Fulham': 4.13779810193623, 'Richmond upon Thames': 4.005161895721457, 'Islington': 4.844048012802297, 'Wandsworth': 4.75770934773927, 'Hackney': 6.198285561008663, 'Barnet': 4.358195917538044, 'Haringey': 5.134624964136042, 'Merton': 4.741273313294603, 'Kingston upon Thames': 4.270549521484271, 'Lambeth': 4.957751163514062, 'Ealing': 4.311450902121834, 'Brent': 4.8945544971392865, 'Harrow': 4.0591964329643195, 'Southwark': 5.516485302379378, 'Bromley': 4.094784685333876, 'Tower Hamlets': 4.62670104006116, 'Waltham Forest': 5.83475580932281, 'Redbridge': 4.471182006097364, 'Hounslow': 3.976409106143329, 'Hillingdon': 4.2002730803844575, 'Enfield': 4.263471583495811, 'Lewisham': 5.449221041059686, 'Greenwich': 4.7630363473291935, 'Sutton': 4.118522608573157, 'Havering': 4.325230371335307, 'Croydon': 4.201100280024766, 'Newham': 5.305390437201879, 'Bexley': 4.248977046127877, 'Barking & Dagenham': 4.89661861291754}

# %%
ratios_dfg = pd.DataFrame([ratios])
ratios_dfg
# Out:
#    Kensington & Chelsea  Westminster    Camden  Hammersmith & Fulham  \
# 0              5.082465     5.353565  4.935353              4.137798
#
#    Richmond upon Thames  Islington  Wandsworth   Hackney    Barnet  Haringey  \
# 0              4.005162   4.844048    4.757709  6.198286  4.358196  5.134625
#
#    ...  Hillingdon   Enfield  Lewisham  Greenwich    Sutton  Havering  \
# 0  ...    4.200273  4.263472  5.449221   4.763036  4.118523   4.32523
#
#    Croydon   Newham    Bexley  Barking & Dagenham
# 0   4.2011  5.30539  4.248977            4.896619
#
# [1 rows x 32 columns]

# %%
ratios_dfg = ratios_dfg.T.reset_index()
ratios_dfg.head()
# Out:
#                   index         0
# 0  Kensington & Chelsea  5.082465
# 1           Westminster  5.353565
# 2                Camden  4.935353
# 3  Hammersmith & Fulham  4.137798
# 4  Richmond upon Thames  4.005162

# %%
ratios_dfg = ratios_dfg.rename(columns={"index": "Borough", 0 : "Ratio of 2018/1998"})
sorted_ratios_dfg = ratios_dfg.sort_values("Ratio of 2018/1998",ascending = False)

# %%
sorted_ratios_dfg
# Out:
#                  Borough  Ratio of 2018/1998
# 7                Hackney            6.198286
# 19        Waltham Forest            5.834756
# 16             Southwark            5.516485
# 24              Lewisham            5.449221
# 1            Westminster            5.353565
# 29                Newham            5.305390
# 9               Haringey            5.134625
# 0   Kensington & Chelsea            5.082465
# 12               Lambeth            4.957751
# 2                 Camden            4.935353
# 31    Barking & Dagenham            4.896619
# 14                 Brent            4.894554
# 5              Islington            4.844048
# 25             Greenwich            4.763036
# 6             Wandsworth            4.757709
# 10                Merton            4.741273
# 18         Tower Hamlets            4.626701
# 20             Redbridge            4.471182
# 8                 Barnet            4.358196
# 27              Havering            4.325230
# 13                Ealing            4.311451
# 11  Kingston upon Thames            4.270550
# 23               Enfield            4.263472
# 30                Bexley            4.248977
# 28               Croydon            4.201100
# 22            Hillingdon            4.200273
# 3   Hammersmith & Fulham            4.137798
# 26                Sutton            4.118523
# 17               Bromley            4.094785
# 15                Harrow            4.059196
# 4   Richmond upon Thames            4.005162
# 21              Hounslow            3.976409

# %%
top_15 = sorted_ratios_dfg.head(15)
top_15
# Out:
#                  Borough  Ratio of 2018/1998
# 7                Hackney            6.198286
# 19        Waltham Forest            5.834756
# 16             Southwark            5.516485
# 24              Lewisham            5.449221
# 1            Westminster            5.353565
# 29                Newham            5.305390
# 9               Haringey            5.134625
# 0   Kensington & Chelsea            5.082465
# 12               Lambeth            4.957751
# 2                 Camden            4.935353
# 31    Barking & Dagenham            4.896619
# 14                 Brent            4.894554
# 5              Islington            4.844048
# 25             Greenwich            4.763036
# 6             Wandsworth            4.757709

# %%
ax = top_15[['Borough','Ratio of 2018/1998']].plot(kind='bar',figsize=(15,8))

ax.set_xticklabels(top_15.Borough);
plt.title('Plot of all boroughs ratio of average home price of 2018/1998');
plt.xlabel("Borough");
plt.ylabel("Ratio of 2018/1998");

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
